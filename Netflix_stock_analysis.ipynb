# %% [markdown]
# # Netflix_stock_analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %%
df=pd.read_csv("Netflix.csv")
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1  2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2  2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3  2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4  2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %% [markdown]
# # OBJECTIVE

# %% [markdown]
# # 1.Voume of stock traded

# %%
sns.set(rc={"figure.figsize":(10,5)})

# %%
df['Date']=pd.to_datetime(df['Date'])
df=df.set_index('Date')
df.head()

# use Date as index instead of counting no
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
sns.lineplot(x=df.index,y=df['Volume'],label='Volume')
plt.title("volume f stock versus time")
# Out:
# Text(0.5, 1.0, 'volume f stock versus time')

# %% [markdown]
# # 2.Netfilx stock price -high,open,close

# %%
df.plot(y=['High','Close','Open'],title="Netflix Stock price")
# Out:
# <Axes: title={'center': 'Netflix Stock price'}, xlabel='Date'>

# %% [markdown]
# # 3.Netfix stock price-Day,month,year wise

# %%
fig,(ax1,ax2,ax3)=plt.subplots(3,figsize=(15,10))

# %%
fig,(ax1,ax2,ax3)=plt.subplots(3,figsize=(15,10))
df.groupby(df.index.day).mean().plot(y='Volume',ax=ax1,xlabel='Day')
df.groupby(df.index.month).mean().plot(y='Volume',ax=ax2,xlabel='Month')
df.groupby(df.index.year).mean().plot(y='Volume',ax=ax3,xlabel='Year')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# # 4.Top-5 Dates with HighestStock Price

# %%
a=df.sort_values(by='High',ascending=False).head(5)
a['High']
# Out:
# Date
# 2021-09-30    619.000000
# 2021-09-08    615.599976
# 2021-09-07    613.849976
# 2021-09-29    609.880005
# 2021-09-10    609.450012
# Name: High, dtype: float64

# %% [markdown]
# # 5.Top-5 Dates with lowest stock price

# %%
b=df.sort_values(by='Low',ascending=True).head(5)
b['Low']
# Out:
# Date
# 2002-10-10    0.346429
# 2002-10-09    0.347143
# 2002-10-07    0.382143
# 2002-10-08    0.390714
# 2002-10-16    0.442857
# Name: Low, dtype: float64

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,sharex=True,figsize=(12,5))

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,sharex=True,figsize=(12,5))
fig.suptitle('High & Low Values stock per period of time ',fontsize=10)
sns.lineplot(ax=axes[0],y=df['High'],x=df.index,color='green')
sns.lineplot(ax=axes[1],y=df['Low'],x=df.index,color='red')
# Out:
# <Axes: xlabel='Date', ylabel='Low'>

# %% [raw]
# This project involves an analysis of Netflix's stock data over a specific period, focusing on various stock price metrics such as Volume, Open, High, and Close. The data is presented visually and statistically to provide insights into Netflix’s market performance.
#
# Here are the key steps and insights of the project:
#
# Data Loading and Preprocessing:
# The project begins with loading a CSV file containing historical stock data for Netflix. The data includes columns like Date, Open, High, Low, Close, Volume, and Adj Close.
# The Date column is converted into a datetime format and set as the index of the dataframe for time series analysis.
#
# Visualizing Stock Volume Over Time:
# A line plot is generated to show how the Volume of Netflix stock changes over time. This provides a clear visual of trading activity.
#
#
# Stock Price Comparison:
# A plot comparing High, Close, and Open stock prices over time is generated to understand the fluctuations in stock values during the analyzed period.
#
#
# Group-wise Analysis:
# The data is grouped by Day, Month, and Year to calculate and visualize the average stock volume. This helps in understanding how stock volume behavior differs over short (daily), medium (monthly), and long-term (yearly) periods.
#
#
#
# Top Stock Values:
# The top 5 highest High values and the lowest Low values are identified and printed. These are the moments when Netflix stock reached its peak and bottom within the data period.
#
#
# Comparing High and Low Stock Values:
# Two line plots are created to compare the High and Low stock values over time. This allows us to visually observe the patterns in stock price movements and how Netflix’s stock fluctuates throughout the period.
#
#
# Tools and Libraries Used:
# Pandas: For data manipulation and analysis.
# Matplotlib & Seaborn: For creating various types of visualizations such as line plots, and comparing stock values.
# Datetime: For handling and converting the date-related data into a time series format.
#
#
#
# Project Insights:
# The project offers a clear and intuitive understanding of Netflix stock trends, including the daily, monthly, and yearly patterns.
# It provides actionable insights into when Netflix stock has had high volatility or low trading volumes, which could help in making more informed investment decisions.
#
# In summary, this project demonstrates the ability to manipulate time series data and extract meaningful insights using visualization and aggregation techniques. It could be used by investors, analysts, or financial planners to assess the stock's past performance and trends over time.
